# %%
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
import wfdb

# %%
 #https://physionet.org/content/mitdb/1.0.0/
signals, fields = wfdb.rdsamp(r'100' ,pn_dir = 'mitdb')

# %%
print(signals.shape)
print(fields)
# Out:
# (650000, 2)
# {'fs': 360, 'sig_len': 650000, 'n_sig': 2, 'base_date': None, 'base_time': None, 'units': ['mV', 'mV'], 'sig_name': ['MLII', 'V5'], 'comments': ['69 M 1085 1629 x1', 'Aldomet, Inderal']}

# %%
record = signals[:,0]
fs = fields['fs']

plt.plot(record)
plt.show()

plt.plot(record[30000:40000])
plt.show()

# %% [markdown]
# # High Pass Filtering

# %%
filter_order = 1142
filter_coeffs = signal.firwin(filter_order, 0.5/(fs/2), window='hamming')
y = signal.lfilter(filter_coeffs, 1, record)

t = np.linspace(0, 1, record.shape[0])
x = record
fig, ax = plt.subplots()
ax.plot(t, x, label='Original Signal')
ax.plot(t, y, label='Filtered Signal')
ax.legend()
plt.show()

# %%
print(x.shape)
print(y.shape)
# Out:
# (1000,)
# (650000,)
